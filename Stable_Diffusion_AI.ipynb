# %% [markdown]
# # Stable Diffusion AI on Google's Research Infrastucture
#
# ## Fooocus
#
# Fooocus is an image generating software (based on [Gradio](https://www.gradio.app/)).
#
# Fooocus is a rethinking of Stable Diffusion and Midjourney’s designs:
#
# * Learned from Stable Diffusion, the software is offline, open source, and free.
#
# * Learned from Midjourney, the manual tweaking is not needed, and users only need to focus on the prompts and images.
#
# Fooocus has included and automated [lots of inner optimizations and quality improvements](#tech_list). Users can forget all those difficult technical parameters, and just enjoy the interaction between human and computer to "explore new mediums of thought and expanding the imaginative powers of the human species" `[1]`.
#
# Fooocus has simplified the installation. Between pressing "download" and generating the first image, the number of needed mouse clicks is strictly limited to less than 3. Minimal GPU memory requirement is 4GB (Nvidia).

# %% [markdown]
# ## Getting Started
# This program can be run in two ways :-
# - Models saved in temporary memory (Slow)
# - Models saved on Google Drive (Fast)
#
# Models saved on GDrive will load faster and will be more time efficient.\
# Models will need to be downloaded every time the program is run of on temporary memory.
#
# `NOTE: Choosing Google Drive for Model saving requires minimum of free 8 GB storage.`
#
# To choose Google Drive as your primary disk space. Change the varable `Save_to_GDrive` to `True`.

# %% [markdown]
# ## After Start
# After Starting, the program will print two links. Click on the link with the domain name as `gradio.live`. This will take you to an external webpage but the processing will run off of here.

# %%
# <------ Click this to run the program.

Save_to_GDrive = True

# --------- Main Program ----------

try:
  import pygit2
  print('[INFO] Pygit2 is already installed')
except ModuleNotFoundError:
  print('[ERROR] Pygit2 is not installed. Installing...')
  # !pip install pygit2==1.12.2

if Save_to_GDrive == True:
  print('\n[INFO] Script running off of GDrive')
  from google.colab import drive
  drive.mount('/content/drive')
  print("[INFO] Connection to user Gdrive established.")
  # %cd /content/drive/MyDrive
  # !git clone https://github.com/lllyasviel/Fooocus.git
  # %cd /content/drive/MyDrive/Fooocus
  # !python entry_with_update.py --share

else:
  print('\n[INFO] Script running off of temporary disk')
  # %cd /content
  # !git clone https://github.com/lllyasviel/Fooocus.git
  # %cd /content/Fooocus
  # !python entry_with_update.py --share
